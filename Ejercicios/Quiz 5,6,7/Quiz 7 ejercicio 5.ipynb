# %%
import seaborn as sn
import matplotlib.pyplot as plt 

x= [1, 3, 5, 10, 25, 40, 8, 30, 19, 17]
y_bar=[12, 15, 5, 11, 23, 35, 42, 22, 13, 1]
y_line=[12, 15, 5, 11, 23, 35, 42, 22, 13, 1]

#y_line=[2, 5, 7, 9, 52, 145, 74, 3, 2, 1]


sn.set(context='poster', style='white', palette='dark', font='sans-serif', font_scale=0.55, color_codes='y'); #Con la funcion set agregamos un fondo cuadrado a nuestra grafica. 

plt.bar(x,y_bar)
plt.plot(x, y_line, '-o', color='y')
plt.title('Grafica')
plt.show()
